# %% [markdown]
# #### resources
# - https://www.youtube.com/watch?v=_K1OsqCicBY&ab_channel=ThalesSehnK%C3%B6rting
# - https://www.cs.unm.edu/~mueen/DTW.pdf

# %% [markdown]
# why DTW
# - for the core problem of time series classification, Nearest Neighbor DTW is very hard to beat
#   - For all time series, faces, gait, fish and heartbeats, we could design and extract features, and just represent the objects as feature vectors. However, in the dozens of cases where we compared this type of approach to just using DTW on the raw data, DTW almost always wins!
# So, at the very least, try the simplest ideas first, and DTW is very simple
# - easy to implement
#
# issues
# - Efficiency: You can use DTW to search one billion
# subsequences in under two minutes, using all the “tricks”
# shown in this tutorial. However a naïve off-the-shelf recursion based DTW implementation would take six years1.
# - Effectiveness: While DTW is quite robust, there are some
# “silly” things you could do to cripple its effectiveness; not z normalizing, set the wrong warping window, enforcing the
# endpoint constraint in certain datasets…

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Intuition

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# For all time series, faces, gait, fish and heartbeats, we could design and extract
# features, and just represent the objects as feature vectors. However, in the
# dozens of cases where we compared this type of approach to just using DTW on
# the raw data, DTW almost always wins!
# So, at the very least, try the simplest ideas first, and DTW is very simple

# %% [markdown]
# $$
# DTW_q({x}, {x}^\prime) =
#     \min_{\pi \in \mathcal{A}({x}, {x}^\prime)}
#         \left( \sum_{(i, j) \in \pi} d(x_i, x^\prime_j)^q \right)^{\frac{1}{q}}
# $$

# %%
# !pip install fastdtw
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from fastdtw import fastdtw

# %%
distance = fastdtw(data_clip1, data_clip2)[0]
print(“The distance between the two clips is %s” % distance)
